# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/15OrdensDeServico.xlsx'
xlsx_file_path = data_path

# %%
df = pd.read_excel(xlsx_file_path)

# %%
 df.head()
# Out:
#     Ano  Mes     data Distrito            Concelho  \
# 0  2024    1  2024-01   Aveiro  Albergaria-a-Velha
# 1  2024    1  2024-01   Aveiro  Albergaria-a-Velha
# 2  2024    1  2024-01   Aveiro  Albergaria-a-Velha
# 3  2024    1  2024-01   Aveiro  Albergaria-a-Velha
# 4  2024    1  2024-01   Aveiro  Albergaria-a-Velha
#
#                        Freguesia                   Tipo de Serviço  \
# 0  Albergaria-a-Velha e Valmaior     Serviço de Corte e Re-Ligação
# 1  Albergaria-a-Velha e Valmaior  Reposição de Potência Contratada
# 2                     Alquerubim    Redução de Potência Contratada
# 3                     Alquerubim     Servico Alteração Contractual
# 4                     Alquerubim  Reposição de Potência Contratada
#
#    Ordens Serviço Realizadas (#) CodDistritoConcelhoFreguesia
# 0                             15                       010209
# 1                             50                       010209
# 2                              5                       010202
# 3                              1                       010202
# 4                              3                       010202
